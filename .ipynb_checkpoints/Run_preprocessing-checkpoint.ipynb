# %%
from preprocessing import preprocess_EuroSAT
#run preprocessing pipeline
in_dir = "EuroSAT"
ml_data   = "preprocessed_ml"

if __name__ == "__main__":
    classes = preprocess_EuroSAT(in_dir, ml_data)
    print("Finished preprocessing.")
    print("Classes:", classes)
